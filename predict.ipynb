# %%
# %run tf_objdet_api_webcam.py
# Out:
# tf.__version__: 1.10.0
# OpenCV version :  3.4.3
# Load label map
# PATH_TO_LABELS: pepper_label_map.pbtxt
# Convert label map to categories
# Create category index
# Load SSD model
# PATH_TO_CKPT: ./result/ssd_mobilenet_v2_pepper/frozen_inference_graph.pb
# Open webcam
# 3.472979647340299
# 0.1396044070702989
# 0.13399785761476835
# 0.1246816890205964
# 0.12784480749535496
# 0.12837035469090427
# 0.12736330534548634
# 0.1294672046148945
# 0.13035537509915482
# 0.13276459633570878
# 0.1280385201719895
# 0.1283267372670263
# 0.12713110670660654
# 0.12424423191640849
# 0.12426604062834748
# 0.1387927808887264
# 0.13804529797756268
# 0.13552446745049743
# 0.14552098233280522
# 0.1364678011473093
# 0.13070003827215135
# 0.12395687006497713
# 0.12996923261129392
# 0.1248086926960058
# 0.12489549992195902
# 0.12452646230620715
# 0.12498187952610952
# 0.12422498893528586
# 0.12428229025685103
# 0.12364983761062041
# 0.12338770544554985
# 0.12553180116441418
# 0.12368361973303571
# ...
